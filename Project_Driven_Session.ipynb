# %%
for i in range(0, 3):
    for j in range(0, 3):
        print(j)
# Out:
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2

# %%
for i in range(0, 3):
    for j in range(0, 3):
        print(i, j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2

# %%
for i in range(1, 4):
    for j in range(1, i):
        print(i, j)
# Out:
# 2 1
# 3 1
# 3 2

# %%
for i in range(1, 4):
    for j in range(1, i+1):
        print(i, j)
# Out:
# 1 1
# 2 1
# 2 2
# 3 1
# 3 2
# 3 3

# %%
for i in range(5, 0, -1):
    print("*" *i)
# Out:
# *****
# ****
# ***
# **
# *
