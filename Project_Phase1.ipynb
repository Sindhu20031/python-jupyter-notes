# %%
import pandas as pd

# Loading dataset
df = pd.read_csv(r"C:\Users\Sindhu\Downloads\Sales Transaction v.4a.csv")  # change filename accordingly

# Checking rows
print("Shape:", df.shape)  # should show > 1000 rows

# Checking missing values
print("Missing values:\n", df.isnull().sum())
# Out:
# Shape: (536350, 8)
# Missing values:
#  TransactionNo     0
# Date              0
# ProductNo         0
# ProductName       0
# Price             0
# Quantity          0
# CustomerNo       55
# Country           0
# dtype: int64

# %% [markdown]
# # Phase 1: Data Understanding

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Sindhu\Downloads\Sales Transaction v.4a.csv")
df.head()
# Out:
#   TransactionNo       Date ProductNo                          ProductName  \
# 0        581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
# 2        581475  12/9/2019     23235             Storage Tin Vintage Leaf
# 3        581475  12/9/2019     23272    Tree T-Light Holder Willie Winkie
# 4        581475  12/9/2019     23239    Set Of 4 Knick Knack Tins Poppies
#
#    Price  Quantity  CustomerNo         Country
# 0  21.47        12     17490.0  United Kingdom
# 1  10.65        36     13069.0  United Kingdom
# 2  11.53        12     13069.0  United Kingdom
# 3  10.65        12     13069.0  United Kingdom
# 4  11.94         6     13069.0  United Kingdom

# %% [markdown]
# ### 1. What columns are present?

# %%
print("Columns present in the dataset:")
print(df.columns.tolist())
# Out:
# Columns present in the dataset:
# ['TransactionNo', 'Date', 'ProductNo', 'ProductName', 'Price', 'Quantity', 'CustomerNo', 'Country']

# %% [markdown]
# ### 2. What kind of data does each column contain?

# %%
print("Column data types:")
print(df.dtypes)
# Out:
# Column data types:
# TransactionNo     object
# Date              object
# ProductNo         object
# ProductName       object
# Price            float64
# Quantity           int64
# CustomerNo       float64
# Country           object
# dtype: object

# %% [markdown]
# ### 3. Are there any missing values?

# %%
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# TransactionNo     0
# Date              0
# ProductNo         0
# ProductName       0
# Price             0
# Quantity          0
# CustomerNo       55
# Country           0
# dtype: int64

# %% [markdown]
# ### 4. Check for unusual values (like negative quantities or prices)

# %%
print("Rows with negative quantities:")
print(df[df['Quantity'] < 0])
print("\nRows with negative or zero unit price:")
print(df[df['Price'] <= 0])
# Out:
# Rows with negative quantities:
#        TransactionNo       Date ProductNo                       ProductName  \
# 1616         C581484  12/9/2019     23843         Paper Craft Little Birdie
# 1617         C581490  12/9/2019     22178   Victorian Glass Hanging T-Light
# 1618         C581490  12/9/2019     23144   Zinc T-Light Holder Stars Small
# 1619         C581568  12/9/2019     21258        Victorian Sewing Box Large
# 1620         C581569  12/9/2019     84978  Hanging Heart Jar T-Light Holder
# ...              ...        ...       ...                               ...
# 536345       C536548  12/1/2018     22168      Organiser Wood Antique White
# 536346       C536548  12/1/2018     21218            Red Spotty Biscuit Tin
# 536347       C536548  12/1/2018     20957      Porcelain Hanging Bell Small
# 536348       C536548  12/1/2018     22580      Advent Calendar Gingham Sack
# 536349       C536548  12/1/2018     22767        Triple Photo Frame Cornice
#
# ...

# %% [markdown]
# ### 2. View sample data

# %%
print("Sample data (first 5 rows):")
print(df.head())
# Out:
# Sample data (first 5 rows):
#   TransactionNo       Date ProductNo                          ProductName  \
# 0        581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
# 2        581475  12/9/2019     23235             Storage Tin Vintage Leaf
# 3        581475  12/9/2019     23272    Tree T-Light Holder Willie Winkie
# 4        581475  12/9/2019     23239    Set Of 4 Knick Knack Tins Poppies
#
#    Price  Quantity  CustomerNo         Country
# 0  21.47        12     17490.0  United Kingdom
# 1  10.65        36     13069.0  United Kingdom
# 2  11.53        12     13069.0  United Kingdom
# 3  10.65        12     13069.0  United Kingdom
# 4  11.94         6     13069.0  United Kingdom

# %% [markdown]
# ### 3. Check structure

# %%
print("\nDataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536350 entries, 0 to 536349
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   TransactionNo  536350 non-null  object
#  1   Date           536350 non-null  object
#  2   ProductNo      536350 non-null  object
#  3   ProductName    536350 non-null  object
#  4   Price          536350 non-null  float64
#  5   Quantity       536350 non-null  int64
#  6   CustomerNo     536295 non-null  float64
#  7   Country        536350 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.7+ MB
# None

# %% [markdown]
# ### 4. Get summary stats

# %%
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#                Price       Quantity     CustomerNo
# count  536350.000000  536350.000000  536295.000000
# mean       12.662182       9.919347   15227.893178
# std         8.490450     216.662300    1716.582932
# min         5.130000  -80995.000000   12004.000000
# 25%        10.990000       1.000000   13807.000000
# 50%        11.940000       3.000000   15152.000000
# 75%        14.090000      10.000000   16729.000000
# max       660.620000   80995.000000   18287.000000

# %% [markdown]
# ### 5. Find missing values

# %%
print("\nMissing Values in Each Column:")
print(df.isnull().sum())
# Out:
# Missing Values in Each Column:
# TransactionNo     0
# Date              0
# ProductNo         0
# ProductName       0
# Price             0
# Quantity          0
# CustomerNo       55
# Country           0
# dtype: int64

# %% [markdown]
# ###  6. Understand categories

# %%
print("Country counts:")
print(df['Country'].value_counts())
print("\n")

print("ProductName counts:")
print(df['ProductName'].value_counts())
print("\n")

print("CustomerNo counts:")
print(df['CustomerNo'].value_counts())
# Out:
# Country counts:
# Country
# United Kingdom          485095
# Germany                  10675
# France                   10526
# EIRE                      8048
# Belgium                   2539
# Spain                     2430
# Switzerland               2336
# Netherlands               2330
# Portugal                  1848
# Australia                 1704
# Norway                     938
# Austria                    887
# Iceland                    787
# Finland                    692
# Italy                      661
# Channel Islands            629
# Cyprus                     582
# Unspecified                447
# Sweden                     417
# Denmark                    416
# USA                        379
# Japan                      371
# Israel                     358
# Singapore                  215
# Poland                     174
# Hong Kong                  153
# Canada                     150
# Malta                      149
# Greece                      67
# ...

# %% [markdown]
# ## Questions to Answer in Your Report
# # 1) What is the shape of your dataset (rows and columns)?

# %%
print("Shape of dataset:", df.shape)
# Out:
# Shape of dataset: (536350, 8)

# %% [markdown]
# # 2) Which columns contain missing values?

# %%
print(df.isnull().sum())
# Out:
# TransactionNo     0
# Date              0
# ProductNo         0
# ProductName       0
# Price             0
# Quantity          0
# CustomerNo       55
# Country           0
# dtype: int64

# %% [markdown]
# # 3) What are the data types of each column?

# %%
print(df.dtypes)
# Out:
# TransactionNo     object
# Date              object
# ProductNo         object
# ProductName       object
# Price            float64
# Quantity           int64
# CustomerNo       float64
# Country           object
# dtype: object

# %% [markdown]
# # 4) What is the distribution of key fields like:
#
# Gender / Category columns

# %%
print("Country distribution:")
print(df['Country'].value_counts())

# 2. Target variable - Not present, but we can check 'Quantity' as outcome proxy
print("\nQuantity distribution (basic stats):")
print(df['Quantity'].describe())

# 3. Important identifiers
print("\nUnique counts of identifiers:")
print("Unique Transactions:", df['TransactionNo'].nunique())
print("Unique Products:", df['ProductNo'].nunique())
print("Unique Customers:", df['CustomerNo'].nunique())

# 4. Price distribution (important score)
print("\nPrice distribution:")
print(df['Price'].describe())
# Out:
# Country distribution:
# Country
# United Kingdom          485095
# Germany                  10675
# France                   10526
# EIRE                      8048
# Belgium                   2539
# Spain                     2430
# Switzerland               2336
# Netherlands               2330
# Portugal                  1848
# Australia                 1704
# Norway                     938
# Austria                    887
# Iceland                    787
# Finland                    692
# Italy                      661
# Channel Islands            629
# Cyprus                     582
# Unspecified                447
# Sweden                     417
# Denmark                    416
# USA                        379
# Japan                      371
# Israel                     358
# Singapore                  215
# Poland                     174
# Hong Kong                  153
# Canada                     150
# Malta                      149
# Greece                      67
# ...

# %% [markdown]
# # 5) Are there any data quality issues like typos, outliers, or inconsistent formatting?

# %%
# Checking for missing values
print("Missing values:\n", df.isnull().sum())

# Checking unique values in each column (helps find typos or inconsistent formatting)
for col in df.columns:
    print(f"\nUnique values in {col}:")
    print(df[col].unique())

# Checking for outliers in numeric columns
print("\nOutlier check (summary stats):")
print(df.describe())
# Out:
# Missing values:
#  TransactionNo     0
# Date              0
# ProductNo         0
# ProductName       0
# Price             0
# Quantity          0
# CustomerNo       55
# Country           0
# dtype: int64
#
# Unique values in TransactionNo:
# ['581482' '581475' '581476' ... 'C536506' 'C536543' 'C536548']
#
# Unique values in Date:
# ['12/9/2019' '12/8/2019' '12/7/2019' '12/6/2019' '12/5/2019' '12/4/2019'
#  '12/2/2019' '12/1/2019' '11/30/2019' '11/29/2019' '11/28/2019'
#  '11/27/2019' '11/25/2019' '11/24/2019' '11/23/2019' '11/22/2019'
#  '11/21/2019' '11/20/2019' '11/18/2019' '11/17/2019' '11/16/2019'
#  '11/15/2019' '11/14/2019' '11/13/2019' '11/11/2019' '11/10/2019'
#  '11/9/2019' '11/8/2019' '11/7/2019' '11/6/2019' '11/4/2019' '11/3/2019'
#  '11/2/2019' '11/1/2019' '10/31/2019' '10/30/2019' '10/28/2019'
#  '10/27/2019' '10/26/2019' '10/25/2019' '10/24/2019' '10/23/2019'
#  '10/21/2019' '10/20/2019' '10/19/2019' '10/18/2019' '10/17/2019'
# ...
